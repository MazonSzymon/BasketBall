# %% [markdown]
# <a href="https://colab.research.google.com/github/MazonSzymon/BasketBall/blob/master/BasketBall.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import libraries
import pandas as pd
import numpy as np

# %%
# Import dataset
url = 'https://raw.githubusercontent.com/MazonSzymon/BasketBall/master/players_stats_by_season_full_details.csv'
orginal_data = pd.read_csv(url)

# %%
orginal_data.head()
# Out:
#   League       Season  ...       nationality             high_school
# 0    NBA  2019 - 2020  ...     United States     Artesia High School
# 1    NBA  2019 - 2020  ...     United States     Oakland High School
# 2    NBA  2019 - 2020  ...     United States  Moss Point High School
# 3    NBA  2019 - 2020  ...  Greece / Nigeria                     NaN
# 4    NBA  2019 - 2020  ...     United States      Norman High School
#
# [5 rows x 31 columns]

# %%
orginal_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53798 entries, 0 to 53797
# Data columns (total 31 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   League       53798 non-null  object
#  1   Season       53798 non-null  object
#  2   Stage        53798 non-null  object
#  3   Player       53798 non-null  object
#  4   Team         53787 non-null  object
#  5   GP           53798 non-null  int64
#  6   MIN          53798 non-null  float64
#  7   FGM          53798 non-null  int64
#  8   FGA          53798 non-null  int64
#  9   3PM          53798 non-null  int64
#  10  3PA          53798 non-null  int64
#  11  FTM          53798 non-null  int64
#  12  FTA          53798 non-null  int64
#  13  TOV          53798 non-null  int64
#  14  PF           53798 non-null  int64
#  15  ORB          53798 non-null  int64
#  16  DRB          53798 non-null  int64
#  17  REB          53798 non-null  int64
# ...

# %%
df = orginal_data.copy()
df.columns = ['League Name','Season Year','Stage',
                        'Player Full Name','Team name', 'Games Played',
                        'Minutes Played', 'Field Goals Made', 'Field Goals Attempts',
                        '3 Points Made', '3 Points Attempts', 'Free Throws Made',
                        'Free Throws Attempts','Turnovers','Personal Fouls',
                        'Offensive Rebounds','Defensive Rebounds','Rebounds',
                        'Assists','Steals','Blocks',
                        'Points','Birth Year','Births Month',
                        'Birth Date', 'Height (Feet)', 'Height (CM)',
                        'Weight (Pounds)','Weight (KG)','Nationality',
                        'High School']
df.head()
# Out:
#   League Name  Season Year  ...       Nationality             High School
# 0         NBA  2019 - 2020  ...     United States     Artesia High School
# 1         NBA  2019 - 2020  ...     United States     Oakland High School
# 2         NBA  2019 - 2020  ...     United States  Moss Point High School
# 3         NBA  2019 - 2020  ...  Greece / Nigeria                     NaN
# 4         NBA  2019 - 2020  ...     United States      Norman High School
#
# [5 rows x 31 columns]

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53798 entries, 0 to 53797
# Data columns (total 31 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   League Name           53798 non-null  object
#  1   Season Year           53798 non-null  object
#  2   Stage                 53798 non-null  object
#  3   Player Full Name      53798 non-null  object
#  4   Team name             53787 non-null  object
#  5   Games Played          53798 non-null  int64
#  6   Minutes Played        53798 non-null  float64
#  7   Field Goals Made      53798 non-null  int64
#  8   Field Goals Attempts  53798 non-null  int64
#  9   3 Points Made         53798 non-null  int64
#  10  3 Points Attempts     53798 non-null  int64
#  11  Free Throws Made      53798 non-null  int64
#  12  Free Throws Attempts  53798 non-null  int64
#  13  Turnovers             53798 non-null  int64
#  14  Personal Fouls        53798 non-null  int64
# ...

# %%
# Change columns data type
#df['League Name'].value_counts() It should be category type
df['League Name'] = df['League Name'].astype('category')
#df['Season Year'].value_counts() It should be a category type
df['Season Year'] = df['Season Year'].astype('category')
#df['Stage'].value_counts() It should be a category type
df['Stage'] = df['Stage'].astype('category')
# df['Team name'].value_counts() It could be category type
df['Team name'] = df['Team name'].astype('category')
df['Birth Year'] = df['Birth Year'].fillna(0).astype('int')
#df['Nationality'].value_counts() It could be a category type
df['Nationality'] = df['Nationality'].astype('category')

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53798 entries, 0 to 53797
# Data columns (total 31 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   League Name           53798 non-null  category
#  1   Season Year           53798 non-null  category
#  2   Stage                 53798 non-null  category
#  3   Player Full Name      53798 non-null  object
#  4   Team name             53787 non-null  category
#  5   Games Played          53798 non-null  int64
#  6   Minutes Played        53798 non-null  float64
#  7   Field Goals Made      53798 non-null  int64
#  8   Field Goals Attempts  53798 non-null  int64
#  9   3 Points Made         53798 non-null  int64
#  10  3 Points Attempts     53798 non-null  int64
#  11  Free Throws Made      53798 non-null  int64
#  12  Free Throws Attempts  53798 non-null  int64
#  13  Turnovers             53798 non-null  int64
#  14  Personal Fouls        53798 non-null  int64
# ...

# %%
# Delete some not intresting info
df.drop(columns= ['Birth Year','Birth Date','Height (Feet)','Weight (Pounds)'], inplace=True)

# %%
df.head()
# Out:
#   League Name  Season Year  ...       Nationality             High School
# 0         NBA  2019 - 2020  ...     United States     Artesia High School
# 1         NBA  2019 - 2020  ...     United States     Oakland High School
# 2         NBA  2019 - 2020  ...     United States  Moss Point High School
# 3         NBA  2019 - 2020  ...  Greece / Nigeria                     NaN
# 4         NBA  2019 - 2020  ...     United States      Norman High School
#
# [5 rows x 27 columns]

# %%
df[(df['Season Year']== '2019 - 2020') & (df['League Name']  == 'NBA') ].sort_values(by = 'Points', ascending = False)[['Player Full Name','League Name', 'Points','Field Goals Made', '3 Points Made','Free Throws Made']].head(10)
# Out:
#         Player Full Name League Name  ...  3 Points Made  Free Throws Made
# 0           James Harden         NBA  ...            299               692
# 1         Damian Lillard         NBA  ...            270               460
# 2           Devin Booker         NBA  ...            141               468
# 3  Giannis Antetokounmpo         NBA  ...             89               398
# 4             Trae Young         NBA  ...            205               481
# 5            Luka Doncic         NBA  ...            171               426
# 6           Bradley Beal         NBA  ...            170               386
# 7           LeBron James         NBA  ...            148               264
# 8       Donovan Mitchell         NBA  ...            173               278
# 9          Anthony Davis         NBA  ...             72               444
#
# [10 rows x 6 columns]

# %%
df['Field Goals %'] = df['Field Goals Made'] / df['Field Goals Attempts']
df['3 Points %'] = df['3 Points Made'] / df['3 Points Attempts']
df['Free Throws %'] = df['Free Throws Made'] / df['Free Throws Attempts']

# %%
NBA = df[df['League Name'] == 'NBA']
NBA.drop(columns='League Name', inplace = True)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
#Who is the best 3 Shooter in NBA 
NBA[['Season Year','Stage','Player Full Name','Minutes Played','3 Points Made','3 Points %']
    ].sort_values(by = '3 Points %', ascending =  False).head(10)
# Out:
#        Season Year           Stage  ... 3 Points Made  3 Points %
# 21576  2015 - 2016  Regular_Season  ...             1         1.0
# 46798  2006 - 2007  Regular_Season  ...             1         1.0
# 42822  2009 - 2010  Regular_Season  ...             1         1.0
# 44269  2008 - 2009  Regular_Season  ...             1         1.0
# 7517   2018 - 2019        Playoffs  ...             1         1.0
# 53672  1999 - 2000        Playoffs  ...             2         1.0
# 46802  2006 - 2007  Regular_Season  ...             1         1.0
# 52045  2002 - 2003        Playoffs  ...             1         1.0
# 33978  2012 - 2013        Playoffs  ...             1         1.0
# 53560  1999 - 2000  Regular_Season  ...             1         1.0
#
# [10 rows x 6 columns]
